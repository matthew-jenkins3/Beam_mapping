# %%
import pandas

import matplotlib.pyplot as plt

csvFile = pandas.read_csv('measurement_data.csv')


print('test')
# Out:
# test

# %%
plt.figure(figsize=(10, 5))
plt.plot(csvFile.iloc[3].to_list())
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(csvFile.iloc[8].to_list())
plt.show()
